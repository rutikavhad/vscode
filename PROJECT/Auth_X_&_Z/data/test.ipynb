# %%
import httpx

class Requestor:

    def __init__(self):
        self.client = httpx.Client()

    def get(self, url, headers=None):
        return self.client.get(url, headers=headers)

    def post(self, url, data=None, headers=None):
        return self.client.post(url, json=data, headers=headers)

# %%
from scanner.requestor import Requestor

r = Requestor()
res = r.get("http://localhost:3000/#/login")

print(res.status_code)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from scanner.requestor import Requestor
#       3 r = Requestor()
#       4 res = r.get("http://localhost:3000/#/login")
#
# ModuleNotFoundError: No module named 'scanner'
