# %%
import csv
import random
import datetime

# Output file
OUTPUT = "synthetic_captures.csv"

# Safe attack placeholders (you will replace later on your machine)
ATTACK_PLACEHOLDERS = {
    "SQLi": "<SQL_INJECTION_PAYLOAD>",
    "XSS": "<XSS_PAYLOAD>",
    "LFI": "<LOCAL_FILE_INCLUSION_PAYLOAD>",
    "CMD": "<COMMAND_INJECTION_PAYLOAD>",
    "NORMAL": "<NORMAL_REQUEST_BODY>"
}

METHODS = ["GET", "POST"]
USER_AGENTS = [
    "Mozilla/5.0 (X11; Linux x86_64; rv:128.0) Gecko Firefox",
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
]

URLS = [
    "/login.php",
    "/search.php",
    "/profile.php",
    "/products.php",
    "/comments.php"
]

HOST = "192.168.1.10"

def random_timestamp():
    return datetime.datetime.utcnow().isoformat() + "Z"

def generate_capture_block(event_type):
    timestamp_now = random_timestamp()
    client_ip = f"127.0.0.1:{random.randint(30000, 60000)}"
    method = random.choice(METHODS)
    path = random.choice(URLS)
    url = f"http://{HOST}{path}"
    user_agent = random.choice(USER_AGENTS)

    body = ATTACK_PLACEHOLDERS[event_type]

    raw_text = f"""---- CAPTURE START ----
timestamp: {timestamp_now}
client_ip: {client_ip}
method: {method}
url: {url}
path: {path}
---- HEADERS ----
Host: {HOST}
User-Agent: {user_agent}
Accept: */*
---- QUERY ----

---- BODY ----
{body}
---- CACHE-RELATED HEADERS ----
Cache-Control: (none)
Pragma: (none)
Expires: (none)
If-Modified-Since: (none)
If-None-Match: (none)
---- CAPTURE END ----
"""

    return timestamp_now, raw_text

def generate_dataset(rows=400):
    events = ["NORMAL", "SQLi", "XSS", "LFI", "CMD"]

    with open(OUTPUT, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["timestamp", "raw_text"])

        for _ in range(rows):
            event_type = random.choice(events)
            ts, block = generate_capture_block(event_type)
            writer.writerow([ts, block])

    print(f"Dataset created: {OUTPUT}")

# Generate 400+ rows
generate_dataset(rows=450)
# Out:
# Dataset created: synthetic_captures.csv
# /tmp/ipykernel_52031/2416748942.py:34: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.datetime.utcnow().isoformat() + "Z"

# %%
import pandas as pd

df = pd.read_csv("/home/matrix/Documents/vscode/PROJECT/Porject_updated_files/merged_training_data.csv")

# Remove useless columns
df = df.drop(columns=["Unnamed: 0", "timestamp", "Label"], errors="ignore")

# Convert label to integer
df["label"] = df["label"].astype(int)

# Drop rows where raw_text is missing or empty
df = df.dropna(subset=["raw_text"])

# Save clean file
df.to_csv("merged_training_data_clean.csv", index=False)

df.head()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[1], line 9
#       6 df = df.drop(columns=["Unnamed: 0", "timestamp", "Label"], errors="ignore")
#       8 # Convert label to integer
# ----> 9 df["label"] = df["label"].astype(int)
#      11 # Drop rows where raw_text is missing or empty
#      12 df = df.dropna(subset=["raw_text"])
#
# File ~/Documents/vscode/PROJECT/venv/lib/python3.13/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...
